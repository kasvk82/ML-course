# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Проекты\\1. Машинное обучение\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V7\\03-Pandas\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
str(345234523453245)[-4:]
# Out:
# '3245'

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(2345345234545455)
# Out:
# '5455'

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four
# ...

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  quality yelp
# ...

# %%
df['yelp_vect'] = np.vectorize(yelp)(df['total_bill'])

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Проекты/1. Машинное обучение/UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V7/03-Pandas/tips.csv')
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'
'''

# %%
# это фрагменты кода, для которых будет измеряться время выполнения
# (они будут выполняться много раз)
stmt_one = ''' 
df['yelp'] = df['total_bill'].apply(yelp)
'''

stmt_two = '''
df['yelp_vect'] = np.vectorize(yelp)(df['total_bill'])
'''

# %%
import timeit

# %%
timeit.timeit(setup=setup,stmt=stmt_one,number=1000)
# Out:
# 0.33629520001704805

# %%
timeit.timeit(setup=setup,stmt=stmt_two,number=1000)
# Out:
# 0.26128539998899214

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df[(df['yelp'] == '$$$') & (df['total_bill'] < 30)]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, price_per_person, Payer Name, CC Number, Payment ID, yelp]
# Index: []

# %%
def simple(num):
    return num * 2

# %%
simple(2)
# Out:
# 4

# %%
df['total_bill'].apply(simple)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
lambda num: num * 2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda num: num * 2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'Щедрые чаевые'
    else:
        return 'Обычные чаевые'

# %%
quality(16.99, 1.01)
# Out:
# 'Обычные чаевые'

# %%
df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'],df['tip']), axis=1)
# Out:
# 0      Обычные чаевые
# 1      Обычные чаевые
# 2      Обычные чаевые
# 3      Обычные чаевые
# 4      Обычные чаевые
#             ...
# 239    Обычные чаевые
# 240    Обычные чаевые
# 241    Обычные чаевые
# 242    Обычные чаевые
# 243    Обычные чаевые
# Length: 244, dtype: object

# %%
df['quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'],df['tip']), axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID         quality
# ...

# %%
df['quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID         quality
# 0  Christy Cunningham  3560325168603410    Sun2959  Обычные чаевые
# 1      Douglas Tucker  4478071379779230    Sun4608  Обычные чаевые
# 2      Travis Walters  6011812112971322    Sun4458  Обычные чаевые
# 3    Nathaniel Harris  4676137647685994    Sun5260  Обычные чаевые
# 4        Tonya Carter  4832732618637221    Sun2251  Обычные чаевые

# %%
import timeit

# %%
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Проекты/1. Машинное обучение/UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V7/03-Pandas/tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''

# %%
# это фрагменты кода, для которых будет измеряться время выполнения
# (они будут выполняться много раз)
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup=setup,stmt=stmt_one,number=1000)
# Out:
# 4.487594000005629

# %%
timeit.timeit(setup=setup,stmt=stmt_two,number=1000)
# Out:
# 0.5559510999883059

# %%
# Еще один вариант функции (но такой вариант нельзя векторизовать) 
def quality(row):
    if row['tip'] / row['total_bill'] > 0.25:
        return 'Щедрые'
    return 'Обычные'

# %%
df['quality'] = df.apply(quality, axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  quality
# ...
